# %%
import pandas as pd

# %%
df = pd.read_csv("/content/supermarket_sales - Sheet1.csv")

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %% [markdown]
# Based on looking at the datatypes ingested by pandas given fields are only having numerical values, which we will verify further. Also desription of them represents a fact about the transaction records captured. In addition, there are two other fields Date and time, which represents when this transaction has been captured, which represents the fact of the transaction.
#
# ## Columns: Unit price, Quantity, Tax 5%, Total,Payment, cogs, gross margin percentage, gross income, Rating, Date,Time

# %%
df['Unit price'].hist()
# Out:
# <Axes: >

# %%
df['Unit price'].unique()
# Out:
# array([74.69, 15.28, 46.33, 58.22, 86.31, 85.39, 68.84, 73.56, 36.26,
#        54.84, 14.48, 25.51, 46.95, 43.19, 71.38, 93.72, 68.93, 72.61,
#        54.67, 40.3 , 86.04, 87.98, 33.2 , 34.56, 88.63, 52.59, 33.52,
#        87.67, 88.36, 24.89, 94.13, 78.07, 83.78, 96.58, 99.42, 68.12,
#        62.62, 60.88, 54.92, 30.12, 86.72, 56.11, 69.12, 98.7 , 15.37,
#        93.96, 56.69, 20.01, 18.93, 82.63, 91.4 , 44.59, 17.87, 15.43,
#        16.16, 85.98, 44.34, 89.6 , 72.35, 30.61, 24.74, 55.73, 55.07,
#        15.81, 75.74, 15.87, 33.47, 97.61, 78.77, 18.33, 89.48, 62.12,
#        48.52, 75.91, 74.67, 41.65, 49.04, 78.31, 20.38, 99.19, 96.68,
#        19.25, 80.36, 48.91, 83.06, 76.52, 49.38, 42.47, 76.99, 47.38,
#        44.86, 21.98, 64.36, 89.75, 97.16, 87.87, 12.45, 52.75, 82.7 ,
#        48.71, 78.55, 23.07, 58.26, 30.35, 88.67, 27.38, 62.13, 33.98,
#        81.97, 16.49, 98.21, 72.84, 58.07, 80.79, 27.02, 21.94, 51.36,
# ...

# %%
df['Quantity'].hist()
# Out:
# <Axes: >

# %%
df['Quantity'].unique()
# Out:
# array([ 7,  5,  8,  6, 10,  2,  3,  4,  1,  9])

# %%
df['Tax 5%'].hist()
# Out:
# <Axes: >

# %%
df['Tax 5%'].unique()
# Out:
# array([26.1415,  3.82  , 16.2155, 23.288 , 30.2085, 29.8865, 20.652 ,
#        36.78  ,  3.626 ,  8.226 ,  2.896 ,  5.102 , 11.7375, 21.595 ,
#        35.69  , 28.116 , 24.1255, 21.783 ,  8.2005,  4.03  , 21.51  ,
#        13.197 ,  3.32  ,  8.64  , 13.2945, 21.036 ,  1.676 ,  8.767 ,
#        22.09  , 11.2005, 23.5325, 35.1315, 33.512 ,  9.658 , 19.884 ,
#         3.406 , 15.655 , 27.396 , 21.968 , 12.048 ,  4.336 ,  5.611 ,
#        20.736 , 39.48  ,  1.537 , 18.792 , 25.5105,  9.0045,  5.679 ,
#        41.315 , 31.99  , 11.1475,  3.574 ,  0.7715,  1.616 , 34.392 ,
#         4.434 , 35.84  , 36.175 ,  9.183 ,  3.711 , 16.719 , 24.7815,
#         7.905 , 15.148 ,  7.935 ,  3.347 , 29.283 , 39.385 ,  0.9165,
#        44.74  , 31.06  ,  7.278 , 22.773 , 33.6015, 20.825 , 22.068 ,
#        39.155 ,  5.095 , 29.757 , 14.502 ,  7.7   , 16.072 , 12.2275,
#        29.071 , 19.13  , 17.283 ,  2.1235, 23.097 ,  9.476 , 22.43  ,
# ...

# %%
df['Total'].hist()
# Out:
# <Axes: >

# %%
df['Total'].unique()
# Out:
# array([ 548.9715,   80.22  ,  340.5255,  489.048 ,  634.3785,  627.6165,
#         433.692 ,  772.38  ,   76.146 ,  172.746 ,   60.816 ,  107.142 ,
#         246.4875,  453.495 ,  749.49  ,  590.436 ,  506.6355,  457.443 ,
#         172.2105,   84.63  ,  451.71  ,  277.137 ,   69.72  ,  181.44  ,
#         279.1845,  441.756 ,   35.196 ,  184.107 ,  463.89  ,  235.2105,
#         494.1825,  737.7615,  703.752 ,  202.818 ,  417.564 ,   71.526 ,
#         328.755 ,  575.316 ,  461.328 ,  253.008 ,   91.056 ,  117.831 ,
#         435.456 ,  829.08  ,   32.277 ,  394.632 ,  535.7205,  189.0945,
#         119.259 ,  867.615 ,  671.79  ,  234.0975,   75.054 ,   16.2015,
#          33.936 ,  722.232 ,   93.114 ,  752.64  ,  759.675 ,  192.843 ,
#          77.931 ,  351.099 ,  520.4115,  166.005 ,  318.108 ,  166.635 ,
#          70.287 ,  614.943 ,  827.085 ,   19.2465,  939.54  ,  652.26  ,
#         152.838 ,  478.233 ,  705.6315,  437.325 ,  463.428 ,  822.255 ,
# ...

# %%
df['cogs'].hist()
# Out:
# <Axes: >

# %%
df['cogs'].unique()
# Out:
# array([522.83,  76.4 , 324.31, 465.76, 604.17, 597.73, 413.04, 735.6 ,
#         72.52, 164.52,  57.92, 102.04, 234.75, 431.9 , 713.8 , 562.32,
#        482.51, 435.66, 164.01,  80.6 , 430.2 , 263.94,  66.4 , 172.8 ,
#        265.89, 420.72,  33.52, 175.34, 441.8 , 224.01, 470.65, 702.63,
#        670.24, 193.16, 397.68,  68.12, 313.1 , 547.92, 439.36, 240.96,
#         86.72, 112.22, 414.72, 789.6 ,  30.74, 375.84, 510.21, 180.09,
#        113.58, 826.3 , 639.8 , 222.95,  71.48,  15.43,  32.32, 687.84,
#         88.68, 716.8 , 723.5 , 183.66,  74.22, 334.38, 495.63, 158.1 ,
#        302.96, 158.7 ,  66.94, 585.66, 787.7 ,  18.33, 894.8 , 621.2 ,
#        145.56, 455.46, 672.03, 416.5 , 441.36, 783.1 , 101.9 , 595.14,
#        290.04, 154.  , 321.44, 244.55, 581.42, 382.6 , 345.66,  42.47,
#        461.94, 189.52, 448.6 , 153.86, 579.24,  89.75,  97.16, 878.7 ,
#         74.7 , 158.25, 496.2 ,  48.71, 706.95, 207.63, 349.56, 212.45,
# ...

# %%
df['gross margin percentage'].hist()
# Out:
# <Axes: >

# %%
df['gross margin percentage'].unique()
# Out:
# array([4.76190476])

# %%
df['gross income'].hist()
# Out:
# <Axes: >

# %%
df['gross income'].unique()
# Out:
# array([26.1415,  3.82  , 16.2155, 23.288 , 30.2085, 29.8865, 20.652 ,
#        36.78  ,  3.626 ,  8.226 ,  2.896 ,  5.102 , 11.7375, 21.595 ,
#        35.69  , 28.116 , 24.1255, 21.783 ,  8.2005,  4.03  , 21.51  ,
#        13.197 ,  3.32  ,  8.64  , 13.2945, 21.036 ,  1.676 ,  8.767 ,
#        22.09  , 11.2005, 23.5325, 35.1315, 33.512 ,  9.658 , 19.884 ,
#         3.406 , 15.655 , 27.396 , 21.968 , 12.048 ,  4.336 ,  5.611 ,
#        20.736 , 39.48  ,  1.537 , 18.792 , 25.5105,  9.0045,  5.679 ,
#        41.315 , 31.99  , 11.1475,  3.574 ,  0.7715,  1.616 , 34.392 ,
#         4.434 , 35.84  , 36.175 ,  9.183 ,  3.711 , 16.719 , 24.7815,
#         7.905 , 15.148 ,  7.935 ,  3.347 , 29.283 , 39.385 ,  0.9165,
#        44.74  , 31.06  ,  7.278 , 22.773 , 33.6015, 20.825 , 22.068 ,
#        39.155 ,  5.095 , 29.757 , 14.502 ,  7.7   , 16.072 , 12.2275,
#        29.071 , 19.13  , 17.283 ,  2.1235, 23.097 ,  9.476 , 22.43  ,
# ...

# %%
df['Rating'].hist()
# Out:
# <Axes: >

# %%
df['Rating'].unique()
# Out:
# array([ 9.1,  9.6,  7.4,  8.4,  5.3,  4.1,  5.8,  8. ,  7.2,  5.9,  4.5,
#         6.8,  7.1,  8.2,  5.7,  4.6,  6.9,  8.6,  4.4,  4.8,  5.1,  9.9,
#         6. ,  8.5,  6.7,  7.7,  7.5,  7. ,  4.7,  7.6,  7.9,  6.3,  5.6,
#         9.5,  8.1,  6.5,  6.1,  6.6,  5.4,  9.3, 10. ,  6.4,  4.3,  4. ,
#         8.7,  9.4,  5.5,  8.3,  7.3,  4.9,  4.2,  9.2,  7.8,  5.2,  9. ,
#         8.8,  6.2,  9.8,  9.7,  5. ,  8.9])

# %%
df['Date'].unique()
# Out:
# array(['1/5/2019', '3/8/2019', '3/3/2019', '1/27/2019', '2/8/2019',
#        '3/25/2019', '2/25/2019', '2/24/2019', '1/10/2019', '2/20/2019',
#        '2/6/2019', '3/9/2019', '2/12/2019', '2/7/2019', '3/29/2019',
#        '1/15/2019', '3/11/2019', '1/1/2019', '1/21/2019', '3/5/2019',
#        '3/15/2019', '2/17/2019', '3/2/2019', '3/22/2019', '3/10/2019',
#        '1/25/2019', '1/28/2019', '1/7/2019', '3/23/2019', '1/17/2019',
#        '2/2/2019', '3/4/2019', '3/16/2019', '2/27/2019', '2/10/2019',
#        '3/19/2019', '2/3/2019', '3/7/2019', '2/28/2019', '3/27/2019',
#        '1/20/2019', '3/12/2019', '2/15/2019', '3/6/2019', '2/14/2019',
#        '3/13/2019', '1/24/2019', '1/6/2019', '2/11/2019', '1/22/2019',
#        '1/13/2019', '1/9/2019', '1/12/2019', '1/26/2019', '1/23/2019',
#        '2/23/2019', '1/2/2019', '2/9/2019', '3/26/2019', '3/1/2019',
#        '2/1/2019', '3/28/2019', '3/24/2019', '2/5/2019', '1/19/2019',
# ...

# %%
df['Time'].unique()
# Out:
# array(['13:08', '10:29', '13:23', '20:33', '10:37', '18:30', '14:36',
#        '11:38', '17:15', '13:27', '18:07', '17:03', '10:25', '16:48',
#        '19:21', '16:19', '11:03', '10:39', '18:00', '15:30', '11:24',
#        '10:40', '12:20', '11:15', '17:36', '19:20', '15:31', '12:17',
#        '19:48', '15:36', '19:39', '12:43', '14:49', '10:12', '10:42',
#        '12:28', '19:15', '17:17', '13:24', '13:01', '18:45', '10:11',
#        '13:03', '20:39', '19:47', '17:24', '15:47', '12:45', '17:08',
#        '10:19', '15:10', '14:42', '15:46', '11:49', '19:01', '11:26',
#        '11:28', '15:55', '20:36', '17:47', '10:55', '13:40', '12:27',
#        '14:35', '16:40', '15:43', '15:01', '10:04', '18:50', '12:46',
#        '18:17', '18:21', '17:04', '14:20', '15:48', '16:24', '18:56',
#        '19:56', '18:37', '10:17', '14:31', '10:23', '20:35', '16:57',
#        '17:55', '19:54', '16:42', '12:09', '20:05', '20:38', '13:11',
# ...

# %% [markdown]
# Though from datatype, we understand that these fields are numerical, understanding the spread of the data will help us understand, if there are any null values or any business rules available for validation of data.
#
# # Findings:
# - gross margin percentage is same for all the products, and naturally it align with the product rather than the transaction
# - Ratings should generally range from 0 to 10, and it can be used for business rule validation

# %% [markdown]
# Based on general profiling, there are three potential dimension on this dataset - Branch, Customer, product. Let's analyse more of it

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df[['Branch','City']].head()
# Out:
#   Branch       City
# 0      A     Yangon
# 1      C  Naypyitaw
# 2      A     Yangon
# 3      A     Yangon
# 4      A     Yangon

# %%
df[['Branch', 'City']].apply(lambda x: '-'.join(x), axis=1).unique()
# Out:
# array(['A-Yangon', 'C-Naypyitaw', 'B-Mandalay'], dtype=object)

# %%
df[['Customer type','Gender']].head()
# Out:
#   Customer type  Gender
# 0        Member  Female
# 1        Normal  Female
# 2        Normal    Male
# 3        Member    Male
# 4        Normal    Male

# %%
df[['Customer type', 'Gender']].apply(lambda x: '-'.join(x), axis=1).unique()
# Out:
# array(['Member-Female', 'Normal-Female', 'Normal-Male', 'Member-Male'],
#       dtype=object)

# %%
df[['Product line','Unit price','gross margin percentage']].head()
# Out:
#              Product line  Unit price  gross margin percentage
# 0       Health and beauty       74.69                 4.761905
# 1  Electronic accessories       15.28                 4.761905
# 2      Home and lifestyle       46.33                 4.761905
# 3       Health and beauty       58.22                 4.761905
# 4       Sports and travel       86.31                 4.761905

# %%
product_unique = (df['Product line'] + '-' +df['Unit price'].astype(str))

# %%
len(product_unique.unique())
# Out:
# 993

# %%
product_unique.value_counts().head(10)
# Out:
# Sports and travel-45.58         2
# Home and lifestyle-34.42        2
# Home and lifestyle-78.38        2
# Electronic accessories-52.89    2
# Fashion accessories-22.32       2
# Fashion accessories-99.82       2
# Electronic accessories-26.26    2
# Fashion accessories-55.45       1
# Sports and travel-42.97         1
# Sports and travel-17.14         1
# Name: count, dtype: int64

# %%
product_branch = df[['Product line','Unit price','gross margin percentage','Branch']]

# %%
product_branch.head()
# Out:
#              Product line  Unit price  gross margin percentage Branch
# 0       Health and beauty       74.69                 4.761905      A
# 1  Electronic accessories       15.28                 4.761905      C
# 2      Home and lifestyle       46.33                 4.761905      A
# 3       Health and beauty       58.22                 4.761905      A
# 4       Sports and travel       86.31                 4.761905      A

# %%
product_branch['Product line'].unique()
# Out:
# array(['Health and beauty', 'Electronic accessories',
#        'Home and lifestyle', 'Sports and travel', 'Food and beverages',
#        'Fashion accessories'], dtype=object)

# %%
product_branch[product_branch['Product line'] == 'Health and beauty']
# Out:
#           Product line  Unit price  gross margin percentage Branch
# 0    Health and beauty       74.69                 4.761905      A
# 3    Health and beauty       58.22                 4.761905      A
# 8    Health and beauty       36.26                 4.761905      A
# 14   Health and beauty       71.38                 4.761905      A
# 16   Health and beauty       68.93                 4.761905      A
# ..                 ...         ...                      ...    ...
# 983  Health and beauty       99.96                 4.761905      C
# 986  Health and beauty       14.76                 4.761905      B
# 987  Health and beauty       62.00                 4.761905      B
# 989  Health and beauty       75.37                 4.761905      B
# 995  Health and beauty       40.35                 4.761905      C
#
# [152 rows x 4 columns]

# %% [markdown]
# ## Findings:
# - There are 3 potential dimensions on the dataset customer, branch, and product
# - Only two information of customer is captured namely - Customer type and Gender. They have 4 unique values. Creating them as a dimension doesn't make sense as that table won't be true representation of a customer. These four are not the only customers that made the transaction, so representing fact table with only four customers is not a true represntation of data.
# - There are 993 products represented here in the 1000 transaction, they can be considered as dimension. Though we can't confirm these 7 records with same product line and price as same product, for the sake fo simplicity and data availability, we will consider them as same.
# - We can't confirm that unit price is same across the branches for unique product from the dataset. There may be a dynamic pricing, but due to the lack of identifier, we would consider same priced product as single product with same pricing across stores
# - There are 3 branches on three cities , they are a dimension

# %% [markdown]
# # ***Decision***:
#
# - There are two dimensions namely product and branch
# - Product dimension will have product line, unit price, and gross margin
# - Branch dimension will have branch and city
# - Every other field including customer, payment, temporal fields (date, time) will be recorded in fact table. Because they essentialy represent a fact here.
# - There are no identifiers for product in dataset, so surrogate key will be used for both dimension tables
